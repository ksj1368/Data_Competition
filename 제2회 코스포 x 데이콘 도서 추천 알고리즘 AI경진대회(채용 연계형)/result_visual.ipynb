# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action='ignore') 
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
first  = pd.read_csv("/content/drive/MyDrive/Dacon/제2회 코스포 x 데이콘 도서 추천 알고리즘 AI경진대회(채용 연계형)/sub_autogluon_0505_num2_WeightedEnsemble_L4_1st.csv")
first_fillna = pd.read_csv("/content/drive/MyDrive/Dacon/제2회 코스포 x 데이콘 도서 추천 알고리즘 AI경진대회(채용 연계형)/sub_autogluon_0505_num2_WeightedEnsemble_L4_1st_fillna.csv")
second = pd.read_csv('/content/drive/MyDrive/Dacon/제2회 코스포 x 데이콘 도서 추천 알고리즘 AI경진대회(채용 연계형)/sub_autogluon_0505_num2_WeightedEnsemble_L3_2nd.csv')
second_fillna = pd.read_csv("/content/drive/MyDrive/Dacon/제2회 코스포 x 데이콘 도서 추천 알고리즘 AI경진대회(채용 연계형)/sub_autogluon_0505_num2_WeightedEnsemble_L3_2nd_fillna.csv")

# %%
plt.figure(figsize= (30,20))
sns.lineplot(x = range(len(first)), y = first["Book-Rating"], label = "first")
sns.lineplot(x = range(len(first)), y = second["Book-Rating"], label = "second")
plt.show()

# %%
plt.figure(figsize= (30,20))
sns.lineplot(x = range(len(first_fillna)), y = first_fillna["Book-Rating"], label = "first_fillna")
sns.lineplot(x = range(len(first_fillna)), y = second_fillna["Book-Rating"], label = "second_fillna")
plt.show()
